# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadavo6/BioInformaticsProject/blob/main/mini_project_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Proccessing the Database - Part 1
# (Habitat, Taxa and COG files)
#
# > Indented block

# %%
# Run this first to Create Data Dictionaries (Habitat, Taxa, Cog_info)

# Prelimanary Code
# !pip install biopython
from Bio import SeqIO
from datetime import datetime

# Creating Taxa Dictionary
def process_taxa_file():
    data_dict = {}
    with open(taxa_file_name, 'r') as file:
        for line in file:
            parts = line.strip().split(',')
            strain_id = parts[-3]
            bacteria_id = parts[-4]
            phylum_name = parts[1]
            list = [strain_id, phylum_name]
            if (strain_id!='strain_id'):
              data_dict[bacteria_id] = list
    return data_dict

# # Creating cog_info Dictionary
def process_cog_info_file(file_name, encoding='utf-8'):
    data_dict = {}
    with open(file_name, 'r', encoding=encoding, errors='replace') as file:
        for line_number, line in enumerate(file, start=1):
            try:
                parts = line.strip().split(';')
                if len(parts) == 6:
                    cog = parts[0]
                    key = cog[3:]
                    value = parts[1]+';'+parts[2]+';'+parts[3]+';'+parts[4]
                    data_dict[key] = value

            except UnicodeDecodeError as e:
                print(f"Error decoding line {line_number}: {e}")
                print(f"Problematic line content: {line}")
    return data_dict



# Creating Habitat Dictionary
def process_habitat_file():
    data_dict = {}
    with open(habitat_file_name, 'r') as file:
        for line in file:
            parts = line.strip().split(';')
            host_name = parts[1]
            habitat = parts[-1]
            if (host_name!='bacteria'):
              data_dict[host_name] = habitat
    return data_dict


# Main Code

taxa_file_name = 'taxa.txt'
taxa_dict = process_taxa_file()

habitat_file_name = 'habitat.txt'
habitat_dict = process_habitat_file()

cog_file_name = 'COG_INFO_TABLE.txt'
cog_dict = process_cog_info_file(cog_file_name)
# Out:
# Collecting biopython
#   Downloading biopython-1.83-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.25.2)
# Installing collected packages: biopython
# Successfully installed biopython-1.83

# %% [markdown]
# # Extracring Plasmid information - Part 1

# %%
class Genome:
    def __init__(self, Genome_id, creature_name):
        self.Genome_id = Genome_id
        self.creature_name = creature_name
        self.segments = []

def process_file(filename):
    Genomes = {}
    with open(filename, 'r') as file:
        for line in file:
            parts = line.strip().split('#')
            creature_name = parts[3]
            Genome_id = parts[1]
            if Genome_id not in Genomes:
                Genomes[Genome_id] = Genome(Genome_id, creature_name)
            genome = Genomes[Genome_id]
            segments = parts[-1].split()
            current_segment = []
            for segment in segments:
                if segment.isdigit() and len(segment) == 4:
                    current_segment.append(segment)
                else:
                    if current_segment:
                        genome.segments.append(current_segment)
                    current_segment = []
            if current_segment:
                genome.segments.append(current_segment)
    return Genomes

def get_clusters_of_length_d_at_least_q_times(Genomes, d, q):
    segment_counts = {}

    for Genome_id, Genome in Genomes.items():
        for segment in Genome.segments:
            if len(segment) >= d:
                for i in range(len(segment) - d + 1):
                    sub_segment = segment[i:i+d]
                    segment_tuple = tuple(sorted(sub_segment))
                    if segment_tuple in segment_counts:
                        if Genome_id not in segment_counts[segment_tuple]:
                            segment_counts[segment_tuple][Genome_id] = (sub_segment, Genome.creature_name)
                    else:
                        segment_counts[segment_tuple] = {Genome_id: (sub_segment, Genome.creature_name)}

    filtered_clusters = {}
    for segment, genomes in segment_counts.items():
        if len(genomes) >= q:
            filtered_clusters[segment] = genomes
    top_clusters = dict(sorted(filtered_clusters.items(), key=lambda item: len(item[1]), reverse=True)[:5])
    return top_clusters

# Main code
q = 4
d = 2
while (d<5):
  filename = 'cog_words_plasmid.txt'
  start_time = datetime.now()
  Genomes = process_file(filename)

  selected_lists = get_clusters_of_length_d_at_least_q_times(Genomes, d, q)
  timedelta = datetime.now() - start_time
  print(timedelta)
  print()
  print(" "*30 + "Top 20 clusters of length", d, "appearing at least", q, "times:")
  print()
  for segment, cluster_info in selected_lists.items():
      print("Cluster:", segment)
      print("Occurrences:", len(cluster_info))
      print("Genome ID's and Creature Names:")
      for genome_id, (order, creature_name) in cluster_info.items():
          print(f"\tGenome ID: {genome_id}, Creature Name: {creature_name}, Order: {order}")
      print("First Instance of this Cluster:", next(iter(cluster_info.values()))[0])
      print("Information about the COG's:")
      for cog in segment:
        if cog in cog_dict:
          print("\t COG",cog, ":", cog_dict[cog])
        else:
          print("\t COG",cog, ":", "No Information was found for this COG")
      print("Statistics about the different orders we found:")
      word_counter = {}
      host_list = {}
      for value in cluster_info.values():
        word_string = ', '.join(value[0])
        word_counter[word_string] = word_counter.get(word_string, 0) + 1
        host_name = value[1]
        if word_string in host_list:
          host_list[word_string].append(host_name)
        else:
          host_list[word_string]= []
          host_list[word_string].append(host_name)
      for key, value in word_counter.items():
        print("\t [", key , "]:", value, "times out of", len(cluster_info), "which is", round(100*int(value)/len(cluster_info),2), "percent")
      print("Statistics about the Phylum:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Phylum:")
        phylum_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_phylum = taxa_dict[host][1]
          phylum_counter[curr_phylum] = phylum_counter.get(curr_phylum, 0) + 1
        for key, value in phylum_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print("Statistics about the Habitat:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Habitats:")
        habitat_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_habitat = habitat_dict[host]
          habitat_counter[curr_habitat] = habitat_counter.get(curr_habitat, 0) + 1
        for key, value in habitat_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print()
      print("*"*100)
  d = d+1
  print("*"*100)
  print("*"*100)

# %%
  for segment, cluster_info in selected_lists.items():
      print("Cluster:", segment)
      print("Occurrences:", len(cluster_info))
      print("Genome ID's and Creature Names:")
      for genome_id, (order, creature_name) in cluster_info.items():
          print(f"\tGenome ID: {genome_id}, Creature Name: {creature_name}, Order: {order}")
      print("First Instance of this Cluster:", next(iter(cluster_info.values()))[0])
      print("Information about the COG's:")
      for cog in segment:
        if cog in cog_dict:
          print("\t COG",cog, ":", cog_dict[cog])
        else:
          print("\t COG",cog, ":", "No Information was found for this COG")
      print("Statistics about the different orders we found:")
      word_counter = {}
      host_list = {}
      for value in cluster_info.values():
        word_string = ', '.join(value[0])
        word_counter[word_string] = word_counter.get(word_string, 0) + 1
        host_name = value[1]
        if word_string in host_list:
          host_list[word_string].append(host_name)
        else:
          host_list[word_string]= []
          host_list[word_string].append(host_name)
      for key, value in word_counter.items():
        print("\t [", key , "]:", value, "times out of", len(cluster_info), "which is", round(100*int(value)/len(cluster_info),2), "percent")
      print("Statistics about the Phylum:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Phylum:")
        phylum_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_phylum = taxa_dict[host][1]
          phylum_counter[curr_phylum] = phylum_counter.get(curr_phylum, 0) + 1
        for key, value in phylum_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print("Statistics about the Habitat:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Habitats:")
        habitat_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_habitat = habitat_dict[host]
          habitat_counter[curr_habitat] = habitat_counter.get(curr_habitat, 0) + 1
        for key, value in habitat_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print()
      print("*"*100)
  d = d+1
  print("*"*100)
  print("*"*100)

# %% [markdown]
# # Filtering the Bac file - Part 2
#   (Here we clean the chromosomes we don't need from the bac file)
#
# > Indented block

# %%
# Creating host_plasmid List
# This is going over the plasmids, and making a list of every host for their's
def process_plasmid_file(plasmid_file):
    host_list = []
    with open(plasmid_file, 'r') as file:
        for line in file:
          parts = line.strip().split('#')
          host_name = parts[3]
          if host_name not in host_list:
            host_list.append(host_name)
    return host_list

plasmid_file_name = 'cog_words_plasmid.txt'
plasmid_host_list = process_plasmid_file(plasmid_file_name)

# %%
# This Function returns the filtered bac file
def copy_lines_with_condition(input, output, plasmid_search):
    try:
        # Open the bac file in read mode
        with open(input, 'r') as input_file:
            # Filter lines by plasmid_search function
            bacs_that_have_plasmid = [line for line in input_file if plasmid_search(line)]
        # Open a new bac file in write mode
        with open(output_file_name, 'w') as output_file:
            # Write the filtered lines to the new file
            output_file.writelines(bacs_that_have_plasmid)
        return output_file_name

    except FileNotFoundError:
        print(f"The input file '{input_name}' does not exist.")
        return None

# This Function recieves a line, extracts the host's name, and searches for it in plasmid_host list
# returns true if Bac has plasmid, and False if not
def plasmid_search(line):
  chromo_has_plasmid = False
  parts = line.strip().split('#')
  host_name = parts[3]
  for plasmid_host in plasmid_host_list:
    if (plasmid_host == host_name):       ##This checks if this Chromosome's Host has at least one Plasmid
      chromo_has_plasmid = True
  if chromo_has_plasmid:
    return True                   ## True = this host has already a plasmid in our DB
  else:
    return False                ## False = this host does not have a plasmid in our DB


# The main Function
input_file_name = "cog_words_bac.txt"
output_file_name = "new_cog_words_bac.txt"
result_file = copy_lines_with_condition(input_file_name, output_file_name, plasmid_search)

# Downloading the filtered file - will appear in "Downloads"
from google.colab import files
files.download('new_cog_words_bac.txt')

# %% [markdown]
# ### **Here you have to upload the new_cogs_words_bac file from your Downloads (21.1MB)!**

# %% [markdown]
# # Extracring Chromosome information - Part 2

# %%
# REMEMBER TO UPLOAD NEW_COG_WODS_BAC FILE!

class Genome:
    def __init__(self, Genome_id, creature_name):
        self.Genome_id = Genome_id
        self.creature_name = creature_name
        self.segments = []

def process_file(filename):
    Genomes = {}
    with open(filename, 'r') as file:
        for line in file:
            parts = line.strip().split('#')
            creature_name = parts[3]
            Genome_id = parts[1]
            if Genome_id not in Genomes:
                Genomes[Genome_id] = Genome(Genome_id, creature_name)
            genome = Genomes[Genome_id]
            segments = parts[-1].split()
            current_segment = []
            for segment in segments:
                if segment.isdigit() and len(segment) == 4:
                    current_segment.append(segment)
                else:
                    if current_segment:
                        genome.segments.append(current_segment)
                    current_segment = []
            if current_segment:
                genome.segments.append(current_segment)
    return Genomes

def get_clusters_of_length_d_at_least_q_times(Genomes, d, q):
    segment_counts = {}

    for Genome_id, Genome in Genomes.items():
        for segment in Genome.segments:
            if len(segment) >= d:
                for i in range(len(segment) - d + 1):
                    sub_segment = segment[i:i+d]
                    segment_tuple = tuple(sorted(sub_segment))
                    if segment_tuple in segment_counts:
                        if Genome_id not in segment_counts[segment_tuple]:
                            segment_counts[segment_tuple][Genome_id] = (sub_segment, Genome.creature_name)
                    else:
                        segment_counts[segment_tuple] = {Genome_id: (sub_segment, Genome.creature_name)}

    filtered_clusters = {}
    for segment, genomes in segment_counts.items():
        if len(genomes) >= q:
            filtered_clusters[segment] = genomes
    top_clusters = dict(sorted(filtered_clusters.items(), key=lambda item: len(item[1]), reverse=True)[:5])
    return top_clusters

# Main code
q = 5
d = 12
while (d<14):
  filename = 'new_cog_words_bac.txt'
  start_time = datetime.now()
  Genomes = process_file(filename)

  selected_lists = get_clusters_of_length_d_at_least_q_times(Genomes, d, q)
  timedelta = datetime.now() - start_time
  print(timedelta)
  print()
  print(" "*30 + "Top 5 clusters of length", d, "appearing at least", q, "times:")
  print()
  for segment, cluster_info in selected_lists.items():
      print("Cluster:", segment)
      print("Occurrences:", len(cluster_info))
      print("Genome ID's and Creature Names:")
      for genome_id, (order, creature_name) in cluster_info.items():
          print(f"\tGenome ID: {genome_id}, Creature Name: {creature_name}, Order: {order}")
      print("First Instance of this Cluster:", next(iter(cluster_info.values()))[0])
      print("Information about the COG's:")
      for cog in segment:
        if cog in cog_dict:
          print("\t COG",cog, ":", cog_dict[cog])
        else:
          print("\t COG",cog, ":", "No Information was found for this COG")
      print("Statistics about the different orders we found:")
      word_counter = {}
      host_list = {}
      for value in cluster_info.values():
        word_string = ', '.join(value[0])
        word_counter[word_string] = word_counter.get(word_string, 0) + 1
        host_name = value[1]
        if word_string in host_list:
          host_list[word_string].append(host_name)
        else:
          host_list[word_string]= []
          host_list[word_string].append(host_name)
      for key, value in word_counter.items():
        print("\t [", key , "]:", value, "times out of", len(cluster_info), "which is", round(100*int(value)/len(cluster_info),2), "percent")
      print("Statistics about the Phylum:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Phylum:")
        phylum_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_phylum = taxa_dict[host][1]
          phylum_counter[curr_phylum] = phylum_counter.get(curr_phylum, 0) + 1
        for key, value in phylum_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print("Statistics about the Habitat:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Habitats:")
        habitat_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_habitat = habitat_dict[host]
          habitat_counter[curr_habitat] = habitat_counter.get(curr_habitat, 0) + 1
        for key, value in habitat_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print()
      print("*"*100)
  d = d+1
  print("*"*100)
  print("*"*100)
# Out:
# 0:00:02.116897
#
#                               Top 5 clusters of length 12 appearing at least 5 times:
#
# Cluster: ('0088', '0089', '0090', '0091', '0092', '0093', '0094', '0185', '0186', '0197', '0198', '0255')
# Occurrences: 353
# Genome ID's and Creature Names:
# 	Genome ID: NC_009925, Creature Name: Acaryochloris_marina_MBIC11017_uid58167, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013209, Creature Name: Acetobacter_pasteurianus_IFO_3283_01_uid59279, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009484, Creature Name: Acidiphilium_cryptum_JF_5_uid58447, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015186, Creature Name: Acidiphilium_multivorum_AIU301_uid63345, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015850, Creature Name: Acidithiobacillus_caldus_SM_1_uid70791, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015064, Creature Name: Acidobacterium_MP5ACTX9_uid50551, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011586, Creature Name: Acinetobacter_baumannii_AB0057_uid59083, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010410, Creature Name: Acinetobacter_baumannii_AYE_uid61637, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010400, Creature Name: Acinetobacter_baumannii_SDF_uid61601, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010939, Creature Name: Actinobacillus_pleuropneumoniae_serovar_7_AP76_uid59231, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009348, Creature Name: Aeromonas_salmonicida_A449_uid58631, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015183, Creature Name: Agrobacterium_H13_3_uid63403, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011985, Creature Name: Agrobacterium_radiobacter_K84_uid58269, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003062, Creature Name: Agrobacterium_tumefaciens_C58_uid57865, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011989, Creature Name: Agrobacterium_vitis_S4_uid58249, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013205, Creature Name: Alicyclobacillus_acidocaldarius_DSM_446_uid59199, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011312, Creature Name: Aliivibrio_salmonicida_LFI1238_uid59251, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013851, Creature Name: Allochromatium_vinosum_DSM_180_uid46083, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013385, Creature Name: Ammonifex_degensii_KC4_uid41053, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015564, Creature Name: Amycolicicoccus_subflavus_DQS3_9A1_uid67253, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007413, Creature Name: Anabaena_variabilis_ATCC_29413_uid58043, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013171, Creature Name: Anaerococcus_prevotii_DSM_20548_uid59219, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006513, Creature Name: Aromatoleum_aromaticum_EbN1_uid58231, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008711, Creature Name: Arthrobacter_aurescens_TC1_uid58109, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011886, Creature Name: Arthrobacter_chlorophenolicus_A6_uid58969, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008541, Creature Name: Arthrobacter_FB24_uid58141, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007716, Creature Name: Aster_yellows_witches_broom_phytoplasma_AYWB_uid58297, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014816, Creature Name: Asticcacaulis_excentricus_CB_48_uid55641, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013854, Creature Name: Azospirillum_B510_uid46085, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012659, Creature Name: Bacillus_anthracis_A0248_uid59385, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007530, Creature Name: Bacillus_anthracis__Ames_Ancestor__uid58083, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012581, Creature Name: Bacillus_anthracis_CDC_684_uid59303, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012472, Creature Name: Bacillus_cereus_03BB102_uid59299, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011658, Creature Name: Bacillus_cereus_AH187_uid58753, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011773, Creature Name: Bacillus_cereus_AH820_uid58751, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003909, Creature Name: Bacillus_cereus_ATCC_10987_uid57673, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_004722, Creature Name: Bacillus_cereus_ATCC_14579_uid57975, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014335, Creature Name: Bacillus_cereus_biovar_anthracis_CI_uid50615, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006274, Creature Name: Bacillus_cereus_E33L_uid58103, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011772, Creature Name: Bacillus_cereus_G9842_uid58759, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011969, Creature Name: Bacillus_cereus_Q1_uid58529, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014019, Creature Name: Bacillus_megaterium_QM_B1551_uid15862, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013791, Creature Name: Bacillus_pseudofirmus_OF4_uid45847, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008600, Creature Name: Bacillus_thuringiensis_Al_Hakam_uid58795, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014171, Creature Name: Bacillus_thuringiensis_BMB171_uid49135, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_005957, Creature Name: Bacillus_thuringiensis_serovar_konkukian_97_27_uid58089, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010184, Creature Name: Bacillus_weihenstephanensis_KBAB4_uid58315, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003228, Creature Name: Bacteroides_fragilis_NCTC_9343_uid57639, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006347, Creature Name: Bacteroides_fragilis_YCH46_uid58195, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_004663, Creature Name: Bacteroides_thetaiotaomicron_VPI_5482_uid62913, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012846, Creature Name: Bartonella_grahamii_as4aup_uid59405, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010161, Creature Name: Bartonella_tribocorum_CIP_105476_uid59129, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010581, Creature Name: Beijerinckia_indica_ATCC_9039_uid59057, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010816, Creature Name: Bifidobacterium_longum_DJO10A_uid58833, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008277, Creature Name: Borrelia_afzelii_PKo_uid58653, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015921, Creature Name: Borrelia_bissettii_DN127_uid71231, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011728, Creature Name: Borrelia_burgdorferi_ZS7_uid59429, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011229, Creature Name: Borrelia_duttonii_Ly_uid58791, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011244, Creature Name: Borrelia_recurrentis_A1_uid58793, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012225, Creature Name: Brachyspira_hyodysenteriae_WA1_uid59291, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009485, Creature Name: Bradyrhizobium_BTAi1_uid58505, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_002528, Creature Name: Buchnera_aphidicola_APS__Acyrthosiphon_pisum__uid57805, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008513, Creature Name: Buchnera_aphidicola_Cc__Cinara_cedri__uid58579, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008390, Creature Name: Burkholderia_ambifaria_AMMD_uid58303, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010551, Creature Name: Burkholderia_ambifaria_MC40_6_uid58701, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014117, Creature Name: Burkholderia_CCGE1002_uid42523, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008542, Creature Name: Burkholderia_cenocepacia_HI2424_uid58369, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011000, Creature Name: Burkholderia_cenocepacia_J2315_uid57953, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015381, Creature Name: Burkholderia_gladioli_BSR3_uid66301, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012724, Creature Name: Burkholderia_glumae_BGR1_uid59397, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010084, Creature Name: Burkholderia_multivorans_ATCC_17616_uid58697, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010804, Creature Name: Burkholderia_multivorans_ATCC_17616_uid58909, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010681, Creature Name: Burkholderia_phytofirmans_PsJN_uid58729, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009256, Creature Name: Burkholderia_vietnamiensis_G4_uid58075, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014387, Creature Name: Butyrivibrio_proteoclasticus_B316_uid51489, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012034, Creature Name: Caldicellulosiruptor_bescii_DSM_6725_uid59201, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014721, Creature Name: Caldicellulosiruptor_kristjanssonii_177R1B_uid60393, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014758, Creature Name: Calditerrivibrio_nitroreducens_DSM_19672_uid60821, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009802, Creature Name: Campylobacter_concisus_13826_uid58667, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008787, Creature Name: Campylobacter_jejuni_81_176_uid58503, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012039, Creature Name: Campylobacter_lari_RM2100_uid58115, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013194, Creature Name: Candidatus_Accumulibacter_phosphatis_clade_IIA_UW_1_uid59207, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012751, Creature Name: Candidatus_Hamiltonella_defensa_5AT__Acyrthosiphon_pisum__uid59289, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015391, Creature Name: Carnobacterium_17_4_uid65789, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010338, Creature Name: Caulobacter_K31_uid58551, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008254, Creature Name: Chelativorans_BNC1_uid58069, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_002620, Creature Name: Chlamydia_muridarum_Nigg_uid57785, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015470, Creature Name: Chlamydophila_psittaci_6BC_uid63621, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013716, Creature Name: Citrobacter_rodentium_ICC168_uid43089, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009480, Creature Name: Clavibacter_michiganensis_NCPPB_382_uid61625, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010407, Creature Name: Clavibacter_michiganensis_sepedonicus_uid61577, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003030, Creature Name: Clostridium_acetobutylicum_ATCC_824_uid57677, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015687, Creature Name: Clostridium_acetobutylicum_DSM_1731_uid68293, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010520, Creature Name: Clostridium_botulinum_A3_Loch_Maree_uid59149, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009495, Creature Name: Clostridium_botulinum_A_ATCC_3502_uid61579, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010516, Creature Name: Clostridium_botulinum_B1_Okra_uid59147, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012658, Creature Name: Clostridium_botulinum_Ba4_657_uid59173, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010674, Creature Name: Clostridium_botulinum_B_Eklund_17B_uid59159, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009699, Creature Name: Clostridium_botulinum_F_Langeland_uid58929, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009706, Creature Name: Clostridium_kluyveri_DSM_555_uid58885, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011837, Creature Name: Clostridium_kluyveri_NBRC_12016_uid59369, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003366, Creature Name: Clostridium_perfringens_13_uid57681, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008262, Creature Name: Clostridium_perfringens_SM101_uid58117, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011528, Creature Name: Coxiella_burnetii_CbuK_Q154_uid58895, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009727, Creature Name: Coxiella_burnetii_Dugway_5J108_111_uid58629, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010117, Creature Name: Coxiella_burnetii_RSA_331_uid58637, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_002971, Creature Name: Coxiella_burnetii_RSA_493_uid57631, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009778, Creature Name: Cronobacter_sakazakii_ATCC_BAA_894_uid58145, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013282, Creature Name: Cronobacter_turicensis_z3032_uid40821, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007973, Creature Name: Cupriavidus_metallidurans_CH34_uid57815, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015726, Creature Name: Cupriavidus_necator_N_1_uid68689, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010528, Creature Name: Cupriavidus_taiwanensis_LMG_19424_uid61615, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011729, Creature Name: Cyanothece_PCC_7424_uid59025, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011884, Creature Name: Cyanothece_PCC_7425_uid59435, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014501, Creature Name: Cyanothece_PCC_7822_uid52547, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011726, Creature Name: Cyanothece_PCC_8801_uid59027, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013161, Creature Name: Cyanothece_PCC_8802_uid59143, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013939, Creature Name: Deferribacter_desulfuricans_SSM1_uid46653, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012526, Creature Name: Deinococcus_deserti_VCD115_uid58615, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008025, Creature Name: Deinococcus_geothermalis_DSM_11300_uid58275, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015161, Creature Name: Deinococcus_proteolyticus_MRP_uid63399, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_001263, Creature Name: Deinococcus_radiodurans_R1_uid57665, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012108, Creature Name: Desulfobacterium_autotrophicum_HRM2_uid59061, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013223, Creature Name: Desulfohalobium_retbaense_DSM_5692_uid59183, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006138, Creature Name: Desulfotalea_psychrophila_LSv54_uid58153, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012796, Creature Name: Desulfovibrio_magneticus_RS_1_uid59309, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008751, Creature Name: Desulfovibrio_vulgaris_DP4_uid58679, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_002937, Creature Name: Desulfovibrio_vulgaris_Hildenborough_uid57645, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013508, Creature Name: Edwardsiella_tarda_EIB202_uid41819, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009436, Creature Name: Enterobacter_638_uid58727, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015968, Creature Name: Enterobacter_asburiae_LF7a_uid72793, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_004668, Creature Name: Enterococcus_faecalis_V583_uid57669, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013971, Creature Name: Erwinia_amylovora_ATCC_49946_uid46943, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013961, Creature Name: Erwinia_amylovora_CFBP1430_uid46839, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014306, Creature Name: Erwinia_billingiae_Eb661_uid50547, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012214, Creature Name: Erwinia_pyrifoliae_Ep1_96_uid40659, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010694, Creature Name: Erwinia_tasmaniensis_Et1_99_uid59029, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009801, Creature Name: Escherichia_coli_E24377A_uid58395, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013353, Creature Name: Escherichia_coli_O103_H2_12009_uid41013, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013364, Creature Name: Escherichia_coli_O111_H__11128_uid41023, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011601, Creature Name: Escherichia_coli_O127_H6_E2348_69_uid59343, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011353, Creature Name: Escherichia_coli_O157_H7_EC4115_uid59091, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_002655, Creature Name: Escherichia_coli_O157_H7_EDL933_uid57831, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_002695, Creature Name: Escherichia_coli_O157_H7_Sakai_uid57781, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013008, Creature Name: Escherichia_coli_O157_H7_TW14359_uid59235, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013361, Creature Name: Escherichia_coli_O26_H11_11368_uid41021, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013941, Creature Name: Escherichia_coli_O55_H7_CB9615_uid46655, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011742, Creature Name: Escherichia_coli_S88_uid62979, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011415, Creature Name: Escherichia_coli_SE11_uid59425, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010498, Creature Name: Escherichia_coli_SMS_3_5_uid58919, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011751, Creature Name: Escherichia_coli_UMN026_uid62981, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011740, Creature Name: Escherichia_fergusonii_ATCC_35469_uid59375, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012778, Creature Name: Eubacterium_eligens_ATCC_27750_uid59171, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010376, Creature Name: Finegoldia_magna_ATCC_29328_uid58867, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006510, Creature Name: Geobacillus_kaustophilus_HTA426_uid58227, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015660, Creature Name: Geobacillus_thermoglucosidasius_C56_YS93_uid48129, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012793, Creature Name: Geobacillus_WCH70_uid59045, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014915, Creature Name: Geobacillus_Y412MC52_uid55381, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013411, Creature Name: Geobacillus_Y412MC61_uid41171, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014650, Creature Name: Geobacillus_Y4_1MC1_uid55779, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010814, Creature Name: Geobacter_lovleyi_SZ_uid58713, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011365, Creature Name: Gluconacetobacter_diazotrophicus_PAl_5_uid59075, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010125, Creature Name: Gluconacetobacter_diazotrophicus_PAl_5_uid61587, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_016027, Creature Name: Gluconacetobacter_xylinus_NBRC_3288_uid46523, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006677, Creature Name: Gluconobacter_oxydans_621H_uid58239, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015674, Creature Name: Helicobacter_bizzozeronii_CIII_1_uid68141, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009972, Creature Name: Herpetosiphon_aurantiacus_DSM_785_uid58599, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012982, Creature Name: Hirschia_baltica_ATCC_49814_uid59365, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014632, Creature Name: Ilyobacter_polytropus_DSM_2926_uid59769, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014962, Creature Name: Isosphaera_pallida_ATCC_43644_uid62207, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009664, Creature Name: Kineococcus_radiotolerans_SRS30216_uid58067, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009648, Creature Name: Klebsiella_pneumoniae_MGH_78578_uid57619, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012731, Creature Name: Klebsiella_pneumoniae_NTUH_K2044_uid59073, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015214, Creature Name: Lactobacillus_acidophilus_30SC_uid63605, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014724, Creature Name: Lactobacillus_amylovorus_GRL_1112_uid61179, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008497, Creature Name: Lactobacillus_brevis_ATCC_367_uid57989, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015428, Creature Name: Lactobacillus_buchneri_NRRL_B_30929_uid66205, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008526, Creature Name: Lactobacillus_casei_ATCC_334_uid57985, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014334, Creature Name: Lactobacillus_casei_Zhang_uid50673, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013504, Creature Name: Lactobacillus_johnsonii_FI9785_uid41735, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014554, Creature Name: Lactobacillus_plantarum_ST_III_uid53537, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015697, Creature Name: Lactobacillus_reuteri_SD2112_uid55357, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013199, Creature Name: Lactobacillus_rhamnosus_Lc_705_uid59315, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015978, Creature Name: Lactobacillus_sanfranciscensis_TMW_1_1304_uid72937, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008527, Creature Name: Lactococcus_lactis_cremoris_SK11_uid57983, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013656, Creature Name: Lactococcus_lactis_KF147_uid42831, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013861, Creature Name: Legionella_longbeachae_NSW150_uid46099, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006369, Creature Name: Legionella_pneumophila_Lens_uid58209, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006368, Creature Name: Legionella_pneumophila_Paris_uid58211, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010842, Creature Name: Leptospira_biflexa_serovar_Patoc__Patoc_1__Ames__uid58511, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010602, Creature Name: Leptospira_biflexa_serovar_Patoc__Patoc_1__Paris__uid58993, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010471, Creature Name: Leuconostoc_citreum_KM20_uid58481, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014136, Creature Name: Leuconostoc_kimchii_IMSNU_11154_uid48589, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008531, Creature Name: Leuconostoc_mesenteroides_ATCC_8293_uid57919, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003212, Creature Name: Listeria_innocua_Clip11262_uid61567, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013766, Creature Name: Listeria_monocytogenes_uid43671, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010382, Creature Name: Lysinibacillus_sphaericus_C3_41_uid58945, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011999, Creature Name: Macrococcus_caseolyticus_JCSC5402_uid59003, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008740, Creature Name: Marinobacter_aquaeolei_VT8_uid59419, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014759, Creature Name: Marivirga_tractuosa_DSM_4126_uid60837, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014212, Creature Name: Meiothermus_silvanus_DSM_9946_uid49485, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015516, Creature Name: Melissococcus_plutonius_ATCC_35311_uid66803, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_002678, Creature Name: Mesorhizobium_loti_MAFF303099_uid57601, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010511, Creature Name: Methylobacterium_4_46_uid58843, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011894, Creature Name: Methylobacterium_nodulans_ORS_2060_uid59023, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010718, Creature Name: Natranaerobius_thermophilus_JW_NM_WN_LF_uid59001, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007964, Creature Name: Nitrobacter_hamburgensis_X14_uid58293, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013960, Creature Name: Nitrosococcus_halophilus_Nc4_uid46803, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007484, Creature Name: Nitrosococcus_oceani_ATCC_19707_uid58403, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014315, Creature Name: Nitrosococcus_watsonii_C_113_uid50331, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015222, Creature Name: Nitrosomonas_AL212_uid55727, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007614, Creature Name: Nitrosospira_multiformis_ATCC_25196_uid58361, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008699, Creature Name: Nocardioides_JS614_uid58149, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014248, Creature Name: Nostoc_azollae__0708_uid49725, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003272, Creature Name: Nostoc_PCC_7120_uid57803, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010628, Creature Name: Nostoc_punctiforme_PCC_73102_uid57767, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007794, Creature Name: Novosphingobium_aromaticivorans_DSM_12444_uid57747, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015580, Creature Name: Novosphingobium_PP1Y_uid67383, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014761, Creature Name: Oceanithermus_profundus_DSM_14977_uid60855, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009667, Creature Name: Ochrobactrum_anthropi_ATCC_49188_uid58921, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015684, Creature Name: Oligotropha_carboxidovorans_OM5_uid72795, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_016048, Creature Name: Oscillibacter_valericigenes_uid73895, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014622, Creature Name: Paenibacillus_polymyxa_SC2_uid59583, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014837, Creature Name: Pantoea_At_9b_uid55845, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008686, Creature Name: Paracoccus_denitrificans_PD1222_uid58187, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_016078, Creature Name: Pelagibacterium_halotolerans_B2_uid74393, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008609, Creature Name: Pelobacter_propionicus_DSM_2379_uid58255, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012440, Creature Name: Persephonella_marina_EX_H1_uid58119, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011144, Creature Name: Phenylobacterium_zucineum_HLK1_uid58959, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_006370, Creature Name: Photobacterium_profundum_SS9_uid62923, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014148, Creature Name: Planctomyces_limnophilus_DSM_3776_uid48643, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015259, Creature Name: Polymorphum_gilvum_SL003B_26A1_uid65447, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011059, Creature Name: Prosthecochloris_aestuarii_DSM_271_uid58151, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010554, Creature Name: Proteus_mirabilis_HI4320_uid61599, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_005773, Creature Name: Pseudomonas_syringae_phaseolicola_1448A_uid58099, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_004578, Creature Name: Pseudomonas_syringae_tomato_DC3000_uid57967, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015312, Creature Name: Pseudonocardia_dioxanivorans_CB1190_uid65087, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007969, Creature Name: Psychrobacter_cryohalolentis_K5_uid58373, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009524, Creature Name: Psychrobacter_PRwf_1_uid58459, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_015061, Creature Name: Rahnella_Y9602_uid62715, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008313, Creature Name: Ralstonia_eutropha_H16_uid62925, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007347, Creature Name: Ralstonia_eutropha_JMP134_uid58047, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012856, Creature Name: Ralstonia_pickettii_12D_uid58859, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010682, Creature Name: Ralstonia_pickettii_12J_uid58737, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_003295, Creature Name: Ralstonia_solanacearum_GMI1000_uid57593, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_014311, Creature Name: Ralstonia_solanacearum_PSI07_uid50539, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007761, Creature Name: Rhizobium_etli_CFN_42_uid58377, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_010994, Creature Name: Rhizobium_etli_CIAT_652_uid59115, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012850, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM1325_uid58991, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011369, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM2304_uid58997, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008380, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012587, Creature Name: Rhizobium_NGR234_uid59081, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007493, Creature Name: Rhodobacter_sphaeroides_2_4_1_uid57653, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009428, Creature Name: Rhodobacter_sphaeroides_ATCC_17025_uid58451, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_009049, Creature Name: Rhodobacter_sphaeroides_ATCC_17029_uid58449, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_011963, Creature Name: Rhodobacter_sphaeroides_KD131_uid59277, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012490, Creature Name: Rhodococcus_erythropolis_PR4_uid59019, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_008268, Creature Name: Rhodococcus_jostii_RHA1_uid58325, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_012522, Creature Name: Rhodococcus_opacus_B4_uid13791, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_005296, Creature Name: Rhodopseudomonas_palustris_CGA009_uid62901, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_007643, Creature Name: Rhodospirillum_rubrum_ATCC_11170_uid57655, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# 	Genome ID: NC_013501, Creature Name: Rhodothermus_marinus_DSM_4252_uid41729, Order: ['0088', '0089', '0090', '0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094']
# ...
# 	Genome ID: NC_007384, Creature Name: Shigella_sonnei_Ss046_uid58217, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_009636, Creature Name: Sinorhizobium_medicae_WSM419_uid58549, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_003047, Creature Name: Sinorhizobium_meliloti_1021_uid57603, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015590, Creature Name: Sinorhizobium_meliloti_AK83_uid52607, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_007712, Creature Name: Sodalis_glossinidius__morsitans__uid58553, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015593, Creature Name: Sphingobium_chlorophenolicum_L_1_uid52597, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_014006, Creature Name: Sphingobium_japonicum_UT26S_uid47077, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015976, Creature Name: Sphingobium_SYK_6_uid73353, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_009511, Creature Name: Sphingomonas_wittichii_RW1_uid58691, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_008048, Creature Name: Sphingopyxis_alaskensis_RB2256_uid58351, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_013730, Creature Name: Spirosoma_linguale_DSM_74_uid43413, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_013450, Creature Name: Staphylococcus_aureus_ED98_uid41455, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_009632, Creature Name: Staphylococcus_aureus_JH1_uid58457, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_009487, Creature Name: Staphylococcus_aureus_JH9_uid58455, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_002953, Creature Name: Staphylococcus_aureus_MSSA476_uid57841, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_002758, Creature Name: Staphylococcus_aureus_Mu50_uid57835, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_002745, Creature Name: Staphylococcus_aureus_N315_uid57837, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_007793, Creature Name: Staphylococcus_aureus_USA300_FPR3757_uid58555, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_010079, Creature Name: Staphylococcus_aureus_USA300_TCH1516_uid58925, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_002976, Creature Name: Staphylococcus_epidermidis_RP62A_uid57663, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_007168, Creature Name: Staphylococcus_haemolyticus_JCSC1435_uid62919, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_007350, Creature Name: Staphylococcus_saprophyticus_ATCC_15305_uid58411, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_013515, Creature Name: Streptobacillus_moniliformis_DSM_12112_uid41863, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015215, Creature Name: Streptococcus_gallolyticus_ATCC_BAA_2069_uid63617, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_008532, Creature Name: Streptococcus_thermophilus_LMD_9_uid58327, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_003155, Creature Name: Streptomyces_avermitilis_MA_4680_uid57739, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_016111, Creature Name: Streptomyces_cattleya_NRRL_8057_uid77117, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_003888, Creature Name: Streptomyces_coelicolor_A3_2__uid57801, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_016114, Creature Name: Streptomyces_flavogriseus_ATCC_33331_uid40839, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015957, Creature Name: Streptomyces_violaceusniger_Tu_4113_uid52609, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_013595, Creature Name: Streptosporangium_roseum_DSM_43021_uid42521, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_014762, Creature Name: Sulfuricurvum_kujiense_DSM_16994_uid60789, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_011662, Creature Name: Thauera_MZ1T_uid58987, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_014926, Creature Name: Thermovibrio_ammonificans_HB_1_uid62095, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_016148, Creature Name: Thermovirga_lienii_DSM_17291_uid77129, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_005835, Creature Name: Thermus_thermophilus_HB27_uid58033, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_013889, Creature Name: Thioalkalivibrio_K90mix_uid46181, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015385, Creature Name: Treponema_succinifaciens_DSM_2489_uid65781, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015434, Creature Name: Verrucosispora_maris_AB_18_032_uid66297, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_006840, Creature Name: Vibrio_fischeri_ES114_uid58163, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_011184, Creature Name: Vibrio_fischeri_MJ11_uid58907, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_009783, Creature Name: Vibrio_harveyi_ATCC_BAA_1116_uid58957, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_005139, Creature Name: Vibrio_vulnificus_YJ016_uid58007, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_004344, Creature Name: Wigglesworthia_glossinidia_endosymbiont_of_Glossina_brevipalpis_uid57853, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_003919, Creature Name: Xanthomonas_axonopodis_citri_306_uid57889, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_007508, Creature Name: Xanthomonas_campestris_vesicatoria_85_10_uid58321, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_013530, Creature Name: Xylanimonas_cellulosilytica_DSM_15894_uid41935, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_002488, Creature Name: Xylella_fastidiosa_9a5c_uid57849, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_010577, Creature Name: Xylella_fastidiosa_M23_uid58809, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_008800, Creature Name: Yersinia_enterocolitica_8081_uid57741, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015224, Creature Name: Yersinia_enterocolitica_palearctica_105_5R_r__uid63663, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_010159, Creature Name: Yersinia_pestis_Angola_uid58485, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_008150, Creature Name: Yersinia_pestis_Antiqua_uid58607, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_005810, Creature Name: Yersinia_pestis_biovar_Microtus_91001_uid58037, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_003143, Creature Name: Yersinia_pestis_CO92_uid57621, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_008149, Creature Name: Yersinia_pestis_Nepal516_uid58609, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_009381, Creature Name: Yersinia_pestis_Pestoides_F_uid58619, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_014029, Creature Name: Yersinia_pestis_Z176003_uid47317, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_006155, Creature Name: Yersinia_pseudotuberculosis_IP_32953_uid58157, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_010634, Creature Name: Yersinia_pseudotuberculosis_PB1__uid59153, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_013355, Creature Name: Zymomonas_mobilis_NCIMB_11163_uid41019, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# 	Genome ID: NC_015709, Creature Name: Zymomonas_mobilis_pomaceae_ATCC_29192_uid68445, Order: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# First Instance of this Cluster: ['0185', '0091', '0092', '0197', '0255', '0186', '0093', '0198', '0094', '0199', '0096', '0097', '0256']
# Information about the COG's:
# 	 COG 0091 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L22
# 	 COG 0092 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein S3
# 	 COG 0093 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L14
# 	 COG 0094 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L5
# 	 COG 0096 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein S8
# 	 COG 0097 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L6P/L9E
# 	 COG 0185 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein S19
# 	 COG 0186 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein S17
# 	 COG 0197 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L16/L10AE
# 	 COG 0198 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L24
# 	 COG 0199 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein S14
# 	 COG 0255 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L29
# 	 COG 0256 : J;INFORMATION STORAGE AND PROCESSING;Translation, ribosomal structure and biogenesis;Ribosomal protein L18
# Statistics about the different orders we found:
# 	 [ 0185, 0091, 0092, 0197, 0255, 0186, 0093, 0198, 0094, 0199, 0096, 0097, 0256 ]: 323 times out of 323 which is 100.0 percent
# Statistics about the Phylum:
# 	 Order: [ 0185, 0091, 0092, 0197, 0255, 0186, 0093, 0198, 0094, 0199, 0096, 0097, 0256 ] - Appears in these Phylum:
# 		 Proteobacteria - 192 times out of 323 ,which is 59.44 percent
# 		 Acidobacteria - 1 times out of 323 ,which is 0.31 percent
# 		 Firmicutes - 78 times out of 323 ,which is 24.15 percent
# 		 Actinobacteria - 15 times out of 323 ,which is 4.64 percent
# 		 Tenericutes - 1 times out of 323 ,which is 0.31 percent
# 		 Bacteroidetes - 10 times out of 323 ,which is 3.1 percent
# 		 Spirochaetes - 8 times out of 323 ,which is 2.48 percent
# 		 Deferribacteres - 2 times out of 323 ,which is 0.62 percent
# 		 - - 6 times out of 323 ,which is 1.86 percent
# 		 Chloroflexi - 1 times out of 323 ,which is 0.31 percent
# 		 Fusobacteria - 3 times out of 323 ,which is 0.93 percent
# 		 Planctomycetes - 2 times out of 323 ,which is 0.62 percent
# 		 Aquificae - 2 times out of 323 ,which is 0.62 percent
# 		 Chlorobi - 1 times out of 323 ,which is 0.31 percent
# 		 Synergistetes - 1 times out of 323 ,which is 0.31 percent
# Statistics about the Habitat:
# 	 Order: [ 0185, 0091, 0092, 0197, 0255, 0186, 0093, 0198, 0094, 0199, 0096, 0097, 0256 ] - Appears in these Habitats:
# 		 Not Annotated - 29 times out of 323 ,which is 8.98 percent
# 		 Marine Environment - 22 times out of 323 ,which is 6.81 percent
# 		 Human - 48 times out of 323 ,which is 14.86 percent
# 		 Fresh water - 28 times out of 323 ,which is 8.67 percent
# 		 Animal - 23 times out of 323 ,which is 7.12 percent
# 		 Plant - 25 times out of 323 ,which is 7.74 percent
# 		 Extreme Environments - 16 times out of 323 ,which is 4.95 percent
# 		 Soil and Sediment - 68 times out of 323 ,which is 21.05 percent
# 		 Host - 58 times out of 323 ,which is 17.96 percent
# 		 Wastewater - 5 times out of 323 ,which is 1.55 percent
# 		 Endosymbiont - 1 times out of 323 ,which is 0.31 percent
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************

# %% [markdown]
# # Comparing two Profiles of the same Cluster - Part 2
#
# > Indented block

# %%
#functions for profile comaring
def occurence_score(cluster,db1_clusters,db2_clusters,db1_lines,db2_lines):
  score_chrom = len(db1_clusters[cluster])/(db1_lines)
  score_plas = len(db2_clusters[cluster])/(db2_lines)
  return 100-100*abs(score_chrom-score_plas)

def top_three_score(set1,set2):
  common_elements = set1.intersection(set2)
  return ((len(common_elements)*2)/(len(set1)+len(set2)))*100

def phylum_diversity_score(phl_count1,phl_count2):
  return (1-(abs(phl_count1-phl_count2)/max(phl_count1,phl_count2)))*100



def get_top_three_elements(db,db_clusters,cluster, indicator):
    element_count = {};
    for genome_id in db_clusters[cluster].keys():
      curr_element = str(data_by_indicator(db,genome_id,cluster,db_clusters,indicator))
      if curr_element in element_count and curr_element != "-":
        element_count[curr_element] += 1
      else:
        element_count[curr_element] = 1
    return set(sorted(element_count, key=element_count.get, reverse=True)[:3])

def data_by_indicator(db,genome_id,cluster,db_clusters,indicator):
  host_name = db[genome_id].creature_name
  if(indicator == 2): #phylum
    return taxa_dict[host_name][1]
  if(indicator == 4): #hosts
    return host_name
  if(indicator == 5): #habitats
    return habitat_dict[host_name]
  if(indicator == 6): #orders
    return db_clusters[cluster][genome_id][0]

def score(cluster,db1,db2,db1_clusters,db2_clusters,db1_file,db2_file,score_normalize):
  scores = [];
  #get occurence score.
  scores.append(occurence_score(cluster,db1_clusters,db2_clusters,db1_file,db2_file))
  #get score: phylum. indicator 2 (as numbered in the description)
  top3_phylum_db1 = get_top_three_elements(db1,db1_clusters,cluster,2)
  top3_phylum_db2 = get_top_three_elements(db2,db2_clusters, cluster,2)
  scores.append(top_three_score(top3_phylum_db1,top3_phylum_db2))
  #get score: phylum diversity
  phylum_list_db1 = [];
  phylum_list_db2 = [];
  for genome_id in db1_clusters[cluster].keys():
    host_name = db1[genome_id].creature_name
    curr_phylum = taxa_dict[host_name][1]
    if curr_phylum not in phylum_list_db1:
      phylum_list_db1.append(curr_phylum)
    if curr_phylum not in phylum_list_db2:
      phylum_list_db2.append(curr_phylum)
  scores.append(phylum_diversity_score(len(phylum_list_db1),len(phylum_list_db2)))
  #get score:hosts. indicator 4 (as numbered in the description)
  top3_host_names_db1 = get_top_three_elements(db1,db1_clusters,cluster,4)
  top3_host_names_db2 = get_top_three_elements(db2,db2_clusters, cluster,4)
  scores.append(top_three_score(top3_host_names_db1,top3_host_names_db2))
  #get score: habitats. indicator 5 (as numbered in the description)
  top3_habitats_db1 = get_top_three_elements(db1,db1_clusters,cluster,5)
  top3_habitats_db2 = get_top_three_elements(db2,db2_clusters, cluster,5)
  scores.append(top_three_score(top3_habitats_db1,top3_habitats_db2))
  #get score: orders. indicator 6 (as numbered in the description)
  top3_orders_db1 = get_top_three_elements(db1,db1_clusters,cluster,6)
  top3_orders_db2 = get_top_three_elements(db2,db2_clusters, cluster,6)
  scores.append(top_three_score(top3_habitats_db1,top3_habitats_db2))
  #calculate final score:
  final_score = 0
  for i in range(5):
    final_score += scores[i]*score_normalize[i]
  return final_score


def get_all_clusters_of_length_d_at_least_q_times(Genomes, d, q):
    segment_counts = {}
    for Genome_id, Genome in Genomes.items():
        for segment in Genome.segments:
            if len(segment) >= d:
                for i in range(len(segment) - d + 1):
                    sub_segment = segment[i:i+d]
                    segment_tuple = tuple(sorted(sub_segment))
                    if segment_tuple in segment_counts:
                        if Genome_id not in segment_counts[segment_tuple]:
                            segment_counts[segment_tuple][Genome_id] = (sub_segment, Genome.creature_name)
                    else:
                        segment_counts[segment_tuple] = {Genome_id: (sub_segment, Genome.creature_name)}

    filtered_clusters = {}
    for segment, genomes in segment_counts.items():
        if len(genomes) >= q:
            filtered_clusters[segment] = genomes
    return filtered_clusters

# %%
#data printing function:
def print_data(db,cluster,cluster_dict):
  print("Numbers of appearances: ")
  print(len(cluster_dict[cluster].keys()))
  print("Top 3 phylums:")
  print(get_top_three_elements(db,cluster_dict,cluster,2))
  phylum_list = [];
  for genome_id in cluster_dict[cluster].keys():
    host_name = db[genome_id].creature_name
    curr_phylum = taxa_dict[host_name][1]
    if curr_phylum not in phylum_list:
      phylum_list.append(curr_phylum)
  print("number of phylums: ")
  print(len(phylum_list))
  print("\n")
  print("Top 3 hosts: ")
  print(get_top_three_elements(db,cluster_dict,cluster,4))
  print("\n")
  print("Top 3 habitat: ")
  print( get_top_three_elements(db,cluster_dict,cluster,5))
  print("\n")
  print("Top 3 orders: ")
  print(get_top_three_elements(db,cluster_dict,cluster,6))

# %%
def get_clusters_that_differ_significantly(db1,db2,q1,q2,d,db1_lines,db2_lines,score_normalize,bar_score):
  db1_clusters = get_all_clusters_of_length_d_at_least_q_times(db1,d,q1)
  db2_clusters = get_all_clusters_of_length_d_at_least_q_times(db2,d,q2)
  #get the clusters found in both maps:
  common_clusters = set(db1_clusters.keys()) & set(db2_clusters.keys())
  for cluster in common_clusters:
    curr_score = score(cluster,db1,db2,db1_clusters,db2_clusters,db1_lines,db2_lines,score_normalize)

    if curr_score<bar_score:
      return [cluster,db1_clusters,db2_clusters]

  #if no fitting cluster was found. we return 0
  return 0


#main code:
q1 = 316
q2 = 54
d = 4
score_normalize = [0.1,0.2,0.1,0.2,0.2,0.2]
bar_score = 40
chromosome_filename = 'new_cog_words_bac.txt'
plasmid_filename = 'cog_words_plasmid.txt'
chromosome_file = open(chromosome_filename, 'r')
plasmid_file = open(plasmid_filename, 'r')
lines_chromosome =sum(1 for line in chromosome_file)
lines_plasmid =sum(1 for line in plasmid_file)
chromosome_genomes = process_file(chromosome_filename)
plasmid_genomes = process_file(plasmid_filename)
cluster  = get_clusters_that_differ_significantly(chromosome_genomes,plasmid_genomes,q1,q2,d,lines_chromosome,lines_plasmid,score_normalize,bar_score)
if(cluster == 0):
  print("No cluster found! change query")
else:
  print(" "*30 + "Cluster found: ")
  print(" "*28 , cluster[0])
  print("Data from " + chromosome_filename + ": ")
  print_data(chromosome_genomes,cluster[0],cluster[1])
  print("\n")
  print("\n")
  print("Data from " + plasmid_filename + ": ")
  print_data(plasmid_genomes,cluster[0],cluster[2])
